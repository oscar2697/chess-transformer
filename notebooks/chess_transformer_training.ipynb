# %% [markdown]
# # Chess Transformer Training (Colab/Kaggle)
# CE Policy + MSE Value, checkpoint to checkpoints/best_model.pt

# %%
# !pip install python-chess torch -q
from src.graph_agents.nodes.train import run_train
res=run_train(epochs=2, representation='fen_tokens')
print(res)

# %%
# To use Lichess PGN: download via kaggle or urllib, then call run_train(data_path='data/raw/lichess.pgn')
